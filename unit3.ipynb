# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# For now we install this update of RL-Baselines3 Zoo
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf

# %% [markdown]
# IF AND ONLY IF THE VERSION ABOVE DOES NOT EXIST ANYMORE. UNCOMMENT AND INSTALL THE ONE BELOW

# %%
# !pip install rl_zoo3==2.0.0a9

# %%
# !apt-get install swig cmake ffmpeg

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
# from pyvirtualdisplay import Display

# virtual_display = Display(visible=0, size=(1400, 900))
# virtual_display.start()
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo (to revision update/hf) to c:\users\saifs\appdata\local\temp\pip-req-build-ijijethr
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 7dcbff7e74e7a12c052452181ff353a4dbed313a
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting sb3-contrib>=2.0.0a9 (from rl_zoo3==2.0.0a9)
#   Using cached sb3_contrib-2.3.0a1-py3-none-any.whl.metadata (3.6 kB)
# Collecting gym==0.26.2 (from rl_zoo3==2.0.0a9)
#   Using cached gym-0.26.2-py3-none-any.whl
# Collecting huggingface-sb3>=2.2.1 (from rl_zoo3==2.0.0a9)
#   Using cached huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from rl_zoo3==2.0.0a9) (4.66.1)
# Collecting rich (from rl_zoo3==2.0.0a9)
#   Using cached rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting optuna (from rl_zoo3==2.0.0a9)
#   Using cached optuna-3.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from rl_zoo3==2.0.0a9) (6.0)
# Collecting pytablewriter~=0.64 (from rl_zoo3==2.0.0a9)
#   Using cached pytablewriter-0.64.2-py3-none-any.whl (106 kB)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from gym==0.26.2->rl_zoo3==2.0.0a9) (1.26.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from gym==0.26.2->rl_zoo3==2.0.0a9) (3.0.0)
# Collecting gym-notices>=0.0.4 (from gym==0.26.2->rl_zoo3==2.0.0a9)
#   Using cached gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Requirement already satisfied: huggingface-hub~=0.8 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (0.18.0)
# Collecting wasabi (from huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9)
#   Using cached wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: setuptools>=38.3.0 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from pytablewriter~=0.64->rl_zoo3==2.0.0a9) (65.5.0)
# Collecting DataProperty<2,>=0.55.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Using cached DataProperty-1.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Using cached mbstrdecoder-1.1.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting pathvalidate<3,>=2.3.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Using cached pathvalidate-2.5.2-py3-none-any.whl (20 kB)
# Collecting tabledata<2,>=1.3.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Using cached tabledata-1.3.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Using cached tcolorpy-0.1.4-py3-none-any.whl.metadata (5.7 kB)
# Collecting typepy<2,>=1.2.0 (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Using cached typepy-1.3.2-py3-none-any.whl.metadata (9.3 kB)
# Collecting stable-baselines3<3.0,>=2.3.0a0 (from sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Using cached stable_baselines3-2.3.0a1-py3-none-any.whl.metadata (5.0 kB)
# Collecting alembic>=1.5.0 (from optuna->rl_zoo3==2.0.0a9)
#   Using cached alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna->rl_zoo3==2.0.0a9)
#   Using cached colorlog-6.8.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from optuna->rl_zoo3==2.0.0a9) (23.1)
# Collecting sqlalchemy>=1.3.0 (from optuna->rl_zoo3==2.0.0a9)
#   Using cached SQLAlchemy-2.0.25-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->rl_zoo3==2.0.0a9)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\saifs\appdata\roaming\python\python311\site-packages (from rich->rl_zoo3==2.0.0a9) (2.16.1)
# Requirement already satisfied: colorama in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from tqdm->rl_zoo3==2.0.0a9) (0.4.6)
# Collecting Mako (from alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9)
#   Using cached Mako-1.3.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9) (4.8.0)
# Requirement already satisfied: filelock in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2023.10.0)
# Requirement already satisfied: requests in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2.31.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.0.0a9)
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting chardet<6,>=3.0.4 (from mbstrdecoder<2,>=1.0.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.3.0->optuna->rl_zoo3==2.0.0a9)
#   Using cached greenlet-3.0.3-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (0.29.1)
# Requirement already satisfied: torch>=1.13 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2.1.2)
# Requirement already satisfied: pandas in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (2023.3)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (0.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (1.16.0)
# Requirement already satisfied: sympy in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.12)
# Requirement already satisfied: networkx in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.1.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from Mako->alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.0.9)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from pandas->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.13->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.3.0)
# Using cached huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Using cached sb3_contrib-2.3.0a1-py3-none-any.whl (80 kB)
# Using cached optuna-3.5.0-py3-none-any.whl (413 kB)
# Using cached rich-13.7.0-py3-none-any.whl (240 kB)
# Using cached alembic-1.13.1-py3-none-any.whl (233 kB)
# Using cached DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Using cached SQLAlchemy-2.0.25-cp311-cp311-win_amd64.whl (2.1 MB)
# Using cached stable_baselines3-2.3.0a1-py3-none-any.whl (181 kB)
# Using cached tabledata-1.3.3-py3-none-any.whl (11 kB)
# Using cached tcolorpy-0.1.4-py3-none-any.whl (7.9 kB)
# Using cached typepy-1.3.2-py3-none-any.whl (31 kB)
# Using cached colorlog-6.8.0-py3-none-any.whl (11 kB)
# Using cached wasabi-1.1.2-py3-none-any.whl (27 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached greenlet-3.0.3-cp311-cp311-win_amd64.whl (292 kB)
# Using cached Mako-1.3.0-py3-none-any.whl (78 kB)
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml): started
#   Building wheel for rl_zoo3 (pyproject.toml): finished with status 'done'
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.0.0a9-py3-none-any.whl size=77010 sha256=5d4a50193868366e4c073252359382b16d69cdfa54f6b976bd95ffd8c26d3885
#   Stored in directory: C:\Users\saifs\AppData\Local\Temp\pip-ephem-wheel-cache-sfrzkn78\wheels\88\bc\57\4011c512d8515b0fa029a76996b95391477d172f7698c9e186
# Successfully built rl_zoo3
# Installing collected packages: gym-notices, wasabi, tcolorpy, pathvalidate, mdurl, Mako, gym, greenlet, colorlog, chardet, sqlalchemy, mbstrdecoder, markdown-it-py, typepy, stable-baselines3, rich, huggingface-sb3, alembic, sb3-contrib, optuna, DataProperty, tabledata, pytablewriter, rl_zoo3
# DEPRECATION: Loading egg at c:\users\saifs\appdata\local\programs\python\python311\lib\site-packages\ember-0.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo 'C:\Users\saifs\AppData\Local\Temp\pip-req-build-ijijethr'
#   Running command git checkout -b update/hf --track origin/update/hf
#   branch 'update/hf' set up to track 'origin/update/hf'.
#   Switched to a new branch 'update/hf'
#   Running command git submodule update --init --recursive -q
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\saifs\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\greenlet\\_greenlet.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !python -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/  -c dqn.yml
# Out:
# 2024-01-14 04:44:13.388559: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-14 04:44:13.450833: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-14 04:44:13.451509: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-14 04:44:14.656052: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 3422974257
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 1000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cpu device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.81e+03 |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 489      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 861      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 441      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1902     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.35e+03 |
# |    ep_rew_mean      | 338      |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 452      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3303     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 304      |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 476      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 4210     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.98e+03 |
# |    ep_rew_mean      | 259      |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 484      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4637     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.59e+03 |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 491      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 5102     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.44e+03 |
# |    ep_rew_mean      | 204      |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 497      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 5570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.35e+03 |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 502      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 5973     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.27e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 510      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 6668     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 515      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 7175     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 520      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 7661     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 523      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 8263     |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# 2024-01-14 00:52:32.915009: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-14 00:52:32.987145: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-14 00:52:32.988158: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-14 00:52:34.629802: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 335896035
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 1000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cpu device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.86e+03 |
# |    ep_rew_mean      | 80       |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 300      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 590      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.78e+03 |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 355      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1099     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.75e+03 |
# |    ep_rew_mean      | 97.5     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 371      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1698     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.78e+03 |
# |    ep_rew_mean      | 90       |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 393      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.83e+03 |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 413      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3063     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 427      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 432      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4417     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.88e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 438      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 4939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.9e+03  |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 419      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 5574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 404      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 6289     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 412      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 7092     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 123      |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 415      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 7500     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 128      |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 422      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 8274     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 128      |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 427      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 8870     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 128      |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 433      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 9779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 435      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 10346    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 127      |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 433      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 11486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 421      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 12303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 423      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 12960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 426      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 13807    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 429      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 14453    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 430      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 15280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 434      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 16201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 436      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 16749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 437      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 17214    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 432      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 17933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 428      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 18381    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 417      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 19197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 399      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 20159    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 392      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 20517    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 392      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 21426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 390      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 21965    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.775    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 391      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 22693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 393      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 23177    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 395      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 23713    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.76     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 397      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 24250    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 398      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 24677    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=230.00 +/- 157.51
# Episode length: 2615.00 +/- 728.29
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.62e+03 |
# |    mean_reward      | 230      |
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 347      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 25378    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.744    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 349      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 25874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 352      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 26581    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 355      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 27361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 358      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 28070    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 361      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 28912    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.706    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 361      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 29718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 361      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 30694    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 364      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 31403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.685    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 365      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 31861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.68     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 367      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 32363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.672    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 369      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 33147    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 372      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 33783    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.66     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 373      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 34336    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.651    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 376      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 35236    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.642    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 378      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 36145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 376      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 37197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.624    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 379      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 38020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.617    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 381      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 38731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.612    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 382      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 39212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.602    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 385      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 40171    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 386      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 40674    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.586    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 389      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 41783    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 391      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 42386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.576    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 391      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 42821    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 391      |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 43435    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 391      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 44245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.557    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 392      |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 44753    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 394      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 45737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.543    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 395      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 46199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.535    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 397      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 47009    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.527    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 399      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 47758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 400      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 48573    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.513    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 402      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 49211    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.508    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 401      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 49710    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=184.00 +/- 64.14
# Episode length: 3065.00 +/- 1512.51
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.06e+03 |
# |    mean_reward      | 184      |
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.503    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 363      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 50247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.493    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 363      |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 51216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.486    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 365      |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 51899    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.48     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 366      |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 52565    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.472    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 368      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 53354    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.465    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 369      |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 54036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.458    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 371      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 54745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.452    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 372      |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 55308    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 373      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 55837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 373      |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 56631    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 373      |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 57196    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.428    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 373      |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 57826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.419    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 374      |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 58661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.411    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 376      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 59483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.405    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 377      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 60093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.401    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 377      |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 60545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.396    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 378      |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 61011    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.389    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 379      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 61692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.383    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 380      |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 62373    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.377    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 380      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 62956    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.371    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 380      |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 63535    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.365    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 380      |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 64126    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.358    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 381      |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 64811    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.353    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 382      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 65356    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.345    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 383      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 66201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.337    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 384      |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 66997    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 385      |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 67626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.323    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 387      |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 68352    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.314    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 388      |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 69336    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.31     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 388      |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 69686    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.301    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 387      |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 70575    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.294    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 388      |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 71295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.288    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 389      |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 71911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.283    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 389      |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 72423    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.274    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 390      |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 73283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.267    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 391      |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 73997    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 393      |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 74938    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=140.00 +/- 23.02
# Episode length: 2379.00 +/- 229.95
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.38e+03 |
# |    mean_reward      | 140      |
# | rollout/            |          |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.254    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 368      |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 75330    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.25     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 368      |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 75791    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.244    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 368      |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 76334    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.238    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 368      |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 76981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.232    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 368      |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 77562    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.228    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 368      |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 78023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.219    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 370      |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 78850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.214    |
# | time/               |          |
# |    episodes         | 468      |
# ...
# |    total_timesteps  | 193131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00816  |
# |    n_updates        | 23282    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1024     |
# |    fps              | 51       |
# |    time_elapsed     | 3754     |
# |    total_timesteps  | 193720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00935  |
# |    n_updates        | 23429    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.74e+03 |
# |    ep_rew_mean      | 253      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1028     |
# |    fps              | 51       |
# |    time_elapsed     | 3790     |
# |    total_timesteps  | 194741   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.119    |
# |    n_updates        | 23685    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.73e+03 |
# |    ep_rew_mean      | 253      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1032     |
# |    fps              | 51       |
# |    time_elapsed     | 3810     |
# |    total_timesteps  | 195325   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00468  |
# |    n_updates        | 23831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.71e+03 |
# |    ep_rew_mean      | 252      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1036     |
# |    fps              | 51       |
# |    time_elapsed     | 3842     |
# |    total_timesteps  | 196232   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00405  |
# |    n_updates        | 24057    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.72e+03 |
# |    ep_rew_mean      | 254      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1040     |
# |    fps              | 50       |
# |    time_elapsed     | 3870     |
# |    total_timesteps  | 197033   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00685  |
# |    n_updates        | 24258    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.72e+03 |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1044     |
# |    fps              | 50       |
# |    time_elapsed     | 3894     |
# |    total_timesteps  | 197723   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 24430    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.73e+03 |
# |    ep_rew_mean      | 260      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1048     |
# |    fps              | 50       |
# |    time_elapsed     | 3927     |
# |    total_timesteps  | 198678   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 24669    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.75e+03 |
# |    ep_rew_mean      | 262      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1052     |
# |    fps              | 50       |
# |    time_elapsed     | 3963     |
# |    total_timesteps  | 199691   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0629   |
# |    n_updates        | 24922    |
# ----------------------------------
# Eval num_timesteps=200000, episode_reward=210.00 +/- 164.23
# Episode length: 1875.80 +/- 596.64
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.88e+03 |
# |    mean_reward      | 210      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 200000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 24999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 264      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1056     |
# |    fps              | 50       |
# |    time_elapsed     | 4004     |
# |    total_timesteps  | 200563   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0558   |
# |    n_updates        | 25140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 263      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 49       |
# |    time_elapsed     | 4026     |
# |    total_timesteps  | 201210   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 25302    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 263      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1064     |
# |    fps              | 49       |
# |    time_elapsed     | 4053     |
# |    total_timesteps  | 201979   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00497  |
# |    n_updates        | 25494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.74e+03 |
# |    ep_rew_mean      | 262      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1068     |
# |    fps              | 49       |
# |    time_elapsed     | 4072     |
# |    total_timesteps  | 202509   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0061   |
# |    n_updates        | 25627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.73e+03 |
# |    ep_rew_mean      | 263      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1072     |
# |    fps              | 49       |
# |    time_elapsed     | 4107     |
# |    total_timesteps  | 203520   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00447  |
# |    n_updates        | 25879    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.71e+03 |
# |    ep_rew_mean      | 261      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1076     |
# |    fps              | 49       |
# |    time_elapsed     | 4123     |
# |    total_timesteps  | 203960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00264  |
# |    n_updates        | 25989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.71e+03 |
# |    ep_rew_mean      | 263      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 49       |
# |    time_elapsed     | 4155     |
# |    total_timesteps  | 204859   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.074    |
# |    n_updates        | 26214    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.71e+03 |
# |    ep_rew_mean      | 263      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1084     |
# |    fps              | 49       |
# |    time_elapsed     | 4181     |
# |    total_timesteps  | 205580   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00553  |
# |    n_updates        | 26394    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.69e+03 |
# |    ep_rew_mean      | 262      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1088     |
# |    fps              | 48       |
# |    time_elapsed     | 4214     |
# |    total_timesteps  | 206466   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0298   |
# |    n_updates        | 26616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.69e+03 |
# |    ep_rew_mean      | 261      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 48       |
# |    time_elapsed     | 4250     |
# |    total_timesteps  | 207486   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 26871    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.67e+03 |
# |    ep_rew_mean      | 260      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 48       |
# |    time_elapsed     | 4268     |
# |    total_timesteps  | 208015   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 27003    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.68e+03 |
# |    ep_rew_mean      | 266      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 48       |
# |    time_elapsed     | 4315     |
# |    total_timesteps  | 209319   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 27329    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.67e+03 |
# |    ep_rew_mean      | 265      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 48       |
# |    time_elapsed     | 4338     |
# |    total_timesteps  | 209972   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00627  |
# |    n_updates        | 27492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.66e+03 |
# |    ep_rew_mean      | 262      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 48       |
# |    time_elapsed     | 4361     |
# |    total_timesteps  | 210648   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 27661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.66e+03 |
# |    ep_rew_mean      | 263      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 48       |
# |    time_elapsed     | 4389     |
# |    total_timesteps  | 211414   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00396  |
# |    n_updates        | 27853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.64e+03 |
# |    ep_rew_mean      | 262      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 48       |
# |    time_elapsed     | 4411     |
# |    total_timesteps  | 212048   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.058    |
# |    n_updates        | 28011    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.62e+03 |
# |    ep_rew_mean      | 261      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 47       |
# |    time_elapsed     | 4435     |
# |    total_timesteps  | 212735   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 28183    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.62e+03 |
# |    ep_rew_mean      | 262      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 47       |
# |    time_elapsed     | 4468     |
# |    total_timesteps  | 213630   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00768  |
# |    n_updates        | 28407    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.62e+03 |
# |    ep_rew_mean      | 263      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 47       |
# |    time_elapsed     | 4513     |
# |    total_timesteps  | 214896   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00346  |
# |    n_updates        | 28723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.62e+03 |
# |    ep_rew_mean      | 261      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 47       |
# |    time_elapsed     | 4553     |
# |    total_timesteps  | 215992   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 28997    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.59e+03 |
# |    ep_rew_mean      | 259      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 47       |
# |    time_elapsed     | 4566     |
# |    total_timesteps  | 216369   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0513   |
# |    n_updates        | 29092    |
# ----------------------------------

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps _________  --folder logs/

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name _____________________ -orga _____________________ -f logs/

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
